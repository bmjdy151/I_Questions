# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#read the csv data which is the list of cities with the highest number of waiting childrens in Japan
df = pd.read_csv('./data/waiting-child.csv')

# %%
df.head()
# Out:
#      state city-J       city-E  population(thousand)  %waiting-pop  \
# 0    Hyogo    明石市       Akashi                 297.0         0.235
# 1  Okayama    岡山市      Okayama                 721.0         0.053
# 2    Tokyo   世田谷区     Setagaya                 916.0         0.093
# 3    Tokyo   江戸川区      Edogawa                 695.0         0.077
# 4    Hyogo    西宮市  Nishinomiya                 487.9         0.122
#
#    %waiting-workingF  #waiting  %eldery  #eldery  #female(20-45)  \
# 0              2.560       697     25.4    75.44           44879
# 1              0.491       380     25.9   186.74          114882
# 2              1.059       851     20.1   184.05          161122
# 3              0.851       537     20.8   144.56          115991
# 4              1.321       597     23.3   113.68           78013
#
#    #female working(20-45)  #female working fulltime(20-45)  %female working  \
# 0                   27226                            19341            60.67
# 1                   77387                            57610            67.36
# 2                   80348                            63114            49.87
# 3                   63070                            45906            54.37
# 4                   45187                            31756            57.92
#
#    %female working full
# 0                 43.10
# 1                 50.15
# 2                 39.17
# 3                 39.58
# 4                 40.71

# %%
#Show the scatter plot
plt.style.use('default')
fig,ax = plt.subplots()
scatter_plot = ax.scatter(
    df['%eldery'],
    df['%waiting-workingF'],
    s=df["#female working fulltime(20-45)"]/100,
    c=df["#female working fulltime(20-45)"],
    cmap=plt.cm.Pastel1,
    edgecolor="#ECEFF4",
    linewidth=0.5
)
cbar = fig.colorbar(scatter_plot)
cbar.set_label("population in the city (unit:1000)")
ax.set_xlabel("aging rate in the city")
ax.set_ylabel("waiting children rate in the city")
ax.set_title("Scatter plot of aging ratio & waiting child ratio, of the cities with the highest waiting children")
plt.show()

# %%
#limit the data to the cities which have more than 10000 female full time workers
df10000 = df.loc[df['#female working fulltime(20-45)'] >= 10000]
df10000.head()
# Out:
#      state city-J       city-E  population(thousand)  %waiting-pop  \
# 0    Hyogo    明石市       Akashi                 297.0         0.235
# 1  Okayama    岡山市      Okayama                 721.0         0.053
# 2    Tokyo   世田谷区     Setagaya                 916.0         0.093
# 3    Tokyo   江戸川区      Edogawa                 695.0         0.077
# 4    Hyogo    西宮市  Nishinomiya                 487.9         0.122
#
#    %waiting-workingF  #waiting  %eldery  #eldery  #female(20-45)  \
# 0              2.560       697     25.4    75.44           44879
# 1              0.491       380     25.9   186.74          114882
# 2              1.059       851     20.1   184.05          161122
# 3              0.851       537     20.8   144.56          115991
# 4              1.321       597     23.3   113.68           78013
#
#    #female working(20-45)  #female working fulltime(20-45)  %female working  \
# 0                   27226                            19341            60.67
# 1                   77387                            57610            67.36
# 2                   80348                            63114            49.87
# 3                   63070                            45906            54.37
# 4                   45187                            31756            57.92
#
#    %female working full
# 0                 43.10
# 1                 50.15
# 2                 39.17
# 3                 39.58
# 4                 40.71

# %%
#show the scatter plot again
plt.style.use('default')
fig,ax = plt.subplots()
scatter_plot = ax.scatter(
    df10000['%eldery'],
    df10000['%waiting-workingF'],
    s=df10000["#female working fulltime(20-45)"]/100,
    c=df10000["#female working fulltime(20-45)"],
    cmap=plt.cm.Pastel1,
    edgecolor="#ECEFF4",
    linewidth=0.5
)
cbar = fig.colorbar(scatter_plot)
cbar.set_label("population in the city (unit:1000)")
ax.set_xlabel("aging rate in the city")
ax.set_ylabel("waiting children rate in the city")
ax.set_title("Scatter plot of aging ratio & waiting child ratio, of the cities with the highest waiting children")
for _, row in df10000[['city-E','%eldery','%waiting-workingF']].iterrows():
    xy = row[['%eldery','%waiting-workingF']]
    xytext = xy + (0.01,0)
    ax.annotate(row['city-E'],xy,xytext)
plt.show()
